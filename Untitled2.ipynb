# %%
import numpy as py
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Datta.csv')

# %%
dataset2 = dataset[dataset.tanggal == 1]

# %%
print(dataset2)
# Out:
#       bulan                                      titik_lokasi   kecamatan   \
# 0         6             Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1         6               Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2         6           Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3         6        Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4         6                 Kali / Sungai Sentiong - Jl. Timah  Johar Baru
# ...     ...                                                ...         ...
# 1766      6  Kali Cakung Drain (Jembatan Tinggi-Perbatasan ...      Cakung
# 1767      6                                   PHB Rawa Teratai      Cakung
# 1768      6                                 PHB Rawa Gelam III      Cakung
# 1769      6                                   PHB Metropos KIP      Cakung
# 1770      6                                 PHB Warung Jengkol      Cakung
#
#            wilayah   panjang/luas  satuan_panjang/luas  tanggal  \
# ...

# %%
dataset2.head()
# Out:
#    bulan                                titik_lokasi   kecamatan   \
# 0      6       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1      6         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2      6     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3      6  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4      6           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
#
#         wilayah   panjang/luas  satuan_panjang/luas  tanggal  \
# 0  Jakarta Pusat            464                   m        1
# 1  Jakarta Pusat            464                   m        1
# 2  Jakarta Pusat            464                   m        1
# 3  Jakarta Pusat            606                   m        1
# 4  Jakarta Pusat            310                   m        1
#
#   volume_sampah_perhari(m3)
# 0                         3
# 1                         4
# 2                         4
# 3                         4
# 4                         5

# %%
dataset2 = dataset[dataset.tanggal == 1]

# %%
print(dataset2)
# Out:
#       bulan                                      titik_lokasi   kecamatan   \
# 0         6             Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1         6               Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2         6           Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3         6        Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4         6                 Kali / Sungai Sentiong - Jl. Timah  Johar Baru
# ...     ...                                                ...         ...
# 1766      6  Kali Cakung Drain (Jembatan Tinggi-Perbatasan ...      Cakung
# 1767      6                                   PHB Rawa Teratai      Cakung
# 1768      6                                 PHB Rawa Gelam III      Cakung
# 1769      6                                   PHB Metropos KIP      Cakung
# 1770      6                                 PHB Warung Jengkol      Cakung
#
#            wilayah   panjang/luas  satuan_panjang/luas  tanggal  \
# ...

# %%
dataset2.head(20)
# Out:
#     bulan                                      titik_lokasi      kecamatan   \
# 0       6             Kali / Sungai Sentiong - Ruas Dewi Sri     Johar Baru
# 1       6               Kali / Sungai Sentiong - Ruas Abapon     Johar Baru
# 2       6           Kali / Sungai Sentiong - JL Tanah Tinggi     Johar Baru
# 3       6        Kali / Sungai Sentiong Jl.Galur - Pombensin     Johar Baru
# 4       6                 Kali / Sungai Sentiong - Jl. Timah     Johar Baru
# 5       6                                PHB Kawi Kawi Bawah     Johar Baru
# 6       6                                      PHB Kayu Awet     Johar Baru
# 7       6                                    PHB Pulo Gundul     Johar Baru
# 8       6                               PHB Tanah Tinggi XII     Johar Baru
# 9       6                                      PHB Bala Dewa     Johar Baru
# 10      6                           PHB Percetakan Negara II     Johar Baru
# ...

# %%
dataset3 = dataset2[:13]

# %%
print(dataset3)
# Out:
#     bulan                                titik_lokasi   kecamatan   \
# 0       6       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1       6         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2       6     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3       6  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4       6           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
# 5       6                          PHB Kawi Kawi Bawah  Johar Baru
# 6       6                                PHB Kayu Awet  Johar Baru
# 7       6                              PHB Pulo Gundul  Johar Baru
# 8       6                         PHB Tanah Tinggi XII  Johar Baru
# 9       6                                PHB Bala Dewa  Johar Baru
# 10      6                     PHB Percetakan Negara II  Johar Baru
# 11      6                             PHB Johar Baru V  Johar Baru
# 12      6                             PHB Kampung Rawa  Johar Baru
#
# ...

# %%
dataset3.head()
# Out:
#    bulan                                titik_lokasi   kecamatan   \
# 0      6       Kali / Sungai Sentiong - Ruas Dewi Sri  Johar Baru
# 1      6         Kali / Sungai Sentiong - Ruas Abapon  Johar Baru
# 2      6     Kali / Sungai Sentiong - JL Tanah Tinggi  Johar Baru
# 3      6  Kali / Sungai Sentiong Jl.Galur - Pombensin  Johar Baru
# 4      6           Kali / Sungai Sentiong - Jl. Timah  Johar Baru
#
#         wilayah   panjang/luas  satuan_panjang/luas  tanggal  \
# 0  Jakarta Pusat            464                   m        1
# 1  Jakarta Pusat            464                   m        1
# 2  Jakarta Pusat            464                   m        1
# 3  Jakarta Pusat            606                   m        1
# 4  Jakarta Pusat            310                   m        1
#
#   volume_sampah_perhari(m3)
# 0                         3
# 1                         4
# 2                         4
# 3                         4
# 4                         5
